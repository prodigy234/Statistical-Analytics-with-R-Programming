# %% [markdown]
# # R Functions

# %% [markdown]
# In R, a function is simply a reusable block of code that performs a specific task when you call (run) it.

# %% [markdown]
# Think of it like a machine:
#
# - You give it input (called parameters or arguments)
#
# - It processes the input
#
# - It gives you an output (called return value)

# %% [markdown]
# A function is a block of code which only runs when it is called.
#
# You can pass data, known as parameters, into a function.
#
# A function can return data as a result.

# %% [markdown]
# Why Functions:
#
# - Functions help to avoid repeating code
#
# - They help make the code cleaner and easier to maintain
#
# - They can take inputs and return results

# %% [markdown]
# ## Creating a Function
#
# To create a function, use the function() keyword:

# %%
# How to create a function using the function() keyword.
function_name <- function(parameters) {
    # code to execute
    return(result)
}

# %%
# Example
my_function <- function() { # create a function with the name my_function
  print("Hello World!")
}

# %% [markdown]
# ## Call a Function
#
# To call a function, use the function name followed by parenthesis, like my_function():

# %%
# Calling out the function created
my_function() # call the function named my_function
# Out:
# [1] "Hello World!"

# %% [markdown]
# # Parameters & Arguments
#
# Parameters are the variables listed in the function definition. They act as placeholders for the values the function will receive.
#
# Arguments are the actual values you pass into the function when you call it.
#
# Information can be passed into functions as arguments.
#
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:

# %%
# Function Definition (Parameters) 
add_numbers <- function(a, b) {
    result <- a + b
    return(result)
}
# a and b are the parameters

# %%
# Function Call (Arguments)
add_numbers(5, 4)
# 5 and 4 are the arguments
# Out:
# [1] 9

# %%
# Example

my_function <- function(fname) { # fname is the parameter
  paste(fname, "Griffin") # paste() joins strings together
}

my_function("Peter") 
my_function("Lois")
my_function("Stewie")
# "Peter", "Lois", "Stewie" are arguments
# They are the actual values
# They get assigned to fname
# Out:
# [1] "Peter Griffin"
# [1] "Lois Griffin"
# [1] "Stewie Griffin"

# %% [markdown]
# ## Parameters or Arguments?
#
# The terms "parameter" and "argument" can be used for the same thing: information that are passed into a function.
#
# From a function's perspective:
#
# A parameter is the variable listed inside the parentheses in the function definition.
#
# An argument is the value that is sent to the function when it is called.

# %% [markdown]
# # Number of Arguments
#
# By default, a function must be called with the correct number of arguments. Meaning that if your function expects 2 arguments, you have to call the function with 2 arguments, not more, and not less:

# %%
# Example

# This function expects 2 arguments, and gets 2 arguments:

my_function <- function(fname, lname) {
  paste(fname, lname)
}

my_function("Peter", "Griffin")
# Out:
# [1] "Peter Griffin"

# %% [markdown]
# # PRACTICAL QUESTIONS

# %% [markdown]
# ## (1) Even or Odd Checker
#
# ### Write a function that checks if a number is even or odd.

# %%
check_even_odd <- function(num) {
    if (num %% 2 == 0) {
        return("Even")
    } else {
        return("Odd")
    }
}

# %%
# Checking if the argument is even
check_even_odd(10)
# Out:
# [1] "Even"

# %%
# Checking if the argument is odd
check_even_odd(7)
# Out:
# [1] "Odd"

# %% [markdown]
# ## (2) Pass or Fail System
#
# ### Create a function that takes a score and returns:
#
# - "Pass" if score ≥ 50
#
# - "Fail" if score < 50

# %%
check_result <- function(score) {
  if (score >= 50) {
    return("Pass")
  } else {
    return("Fail")
  }
}

check_result(75)  # Pass
check_result(40)  # Fail
# Out:
# [1] "Pass"
# [1] "Fail"

# %% [markdown]
# ## (3) Positive, Negative or Zero
#
# ### Write a function that checks:
#
# - Positive
#
# - Negative
#
# - Zero

# %%
check_number <- function(x) {
  if (x > 0) {
    return("Positive")
  } else if (x < 0) {
    return("Negative")
  } else {
    return("Zero")
  }
}

check_number(5)    # Positive
check_number(-3)   # Negative
check_number(0)    # Zero
# Out:
# [1] "Positive"
# [1] "Negative"
# [1] "Zero"

# %% [markdown]
# ## (4) Simple Calculator Function
#
# ### Create a function that takes two numbers and an operator (+, -, *, /) and performs the operation.

# %%
calculator <- function(a, b, op) {
  if (op == "+") {
    return(a + b)
  } else if (op == "-") {
    return(a - b)
  } else if (op == "*") {
    return(a * b)
  } else if (op == "/") {
    return(a / b)
  } else {
    return("Invalid operator")
  }
}

calculator(10, 5, "+")  # 15
calculator(10, 5, "*")  # 50
# Out:
# [1] 15
# [1] 50

# %% [markdown]
# ## (5) Investment Return Decision
#
# ### Write a function:
#
# - If ROI ≥ 15% → "Good Investment"
#
# - If ROI between 5%–14% → "Average Investment"
#
# - Otherwise → "Bad Investment"

# %%
investment_decision <- function(roi) {
  if (roi >= 15) {
    return("Good Investment")
  } else if (roi >= 5) {
    return("Average Investment")
  } else {
    return("Bad Investment")
  }
}

investment_decision(20)  # Good Investment
investment_decision(10)  # Average Investment
investment_decision(2)   # Bad Investment
# Out:
# [1] "Good Investment"
# [1] "Average Investment"
# [1] "Bad Investment"

# %%
investment_decision <- function(roi) {
  
  # Remove % sign and convert to numeric
  roi_num <- as.numeric(gsub("%", "", roi))
  
  if (roi_num >= 15) {
    return(paste0(roi, " - Good Investment"))
  } else if (roi_num >= 5) {
    return(paste0(roi, " - Average Investment"))
  } else {
    return(paste0(roi, " - Bad Investment"))
  }
}

# %%
investment_decision(30)
# Out:
# [1] "30 - Good Investment"

# %%
investment_decision <- function(roi) {
  if (roi >= 15) {
    return(paste0(roi,"% - Good Investment")) # The zero "0" means zero space between the values
  } else if (roi >= 5) {
    return(paste0(roi,"% - Average Investment"))
  } else {
    return(paste0(roi,"% - Bad Investment"))
  }
}

investment_decision(4)

# Note: paste0() is a function in R used to join or concatenate values together into one string,
# without adding any space between them.
# Out:
# [1] "4% - Bad Investment"
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
