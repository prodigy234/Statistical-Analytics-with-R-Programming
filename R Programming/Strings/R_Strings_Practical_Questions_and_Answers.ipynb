# %% [markdown]
# # R Strings: Practical Data Analytics Exercises
#
# **Prepared by: Kajola Gbenga**
# **Data Scientist & AI Engineer**
#
# ---
#
# ## Comprehensive Practical Notebook
#
# This notebook covers R string manipulation from beginner to intermediate level, with practical examples focused on **data analytics and data cleaning**.
#
# ### Learning Objectives
# By the end of this notebook, you should be able to:
#
# - Create and print strings in R
# - Measure string length
# - Change string case
# - Extract characters and substrings
# - Replace text
# - Combine strings
# - Search for patterns
# - Split strings
# - Remove unwanted spaces
# - Clean names, emails, and phone numbers
# - Count words
# - Apply string manipulation to practical data-cleaning scenarios
#
# > **Requirement:** Run this notebook with an R kernel such as **IRkernel** in Jupyter Notebook/JupyterLab.

# %% [markdown]
# ## 1. What Is a String in R?
#
# A **string** is a sequence of characters such as a name, sentence, email address, product description, or transaction label.
#
# In R, strings are usually created using either double quotes or single quotes:
#
# ```r
# name <- "Gbenga"
# city <- 'Lagos'
# ```
#
# Strings are particularly important in data analytics because many real-world datasets contain text that needs to be cleaned, transformed, searched, or extracted.

# %% [markdown]
# ## 2. Create and Print a String
#
# ### Practical Question
#
# Create a variable called `name` containing your name and print it.
#
# ### Answer
#
# ```r
# name <- "Gbenga"
# print(name)
# ```

# %% [markdown]
# **Explanation:** `<-` assigns a value to a variable, while `print()` displays the value.

# %%
name <- "Gbenga"
print(name)
# Out:
# [1] "Gbenga"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "Gbenga"
# ```

# %% [markdown]
# ## 3. Find the Length of a String
#
# ### Practical Question
#
# Given `name <- "Data Science"`, find the number of characters in the string.
#
# ### Answer
#
# ```r
# name <- "Data Science"
# nchar(name)
# ```

# %% [markdown]
# **Explanation:** `nchar()` counts characters, including spaces.

# %%
name <- "Data Science"
nchar(name)
# Out:
# [1] 12

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] 12
# ```

# %% [markdown]
# ## 4. Convert a String to Uppercase
#
# ### Practical Question
#
# Convert `"data scientist"` to uppercase.
#
# ### Answer
#
# ```r
# job <- "data scientist"
# toupper(job)
# ```

# %% [markdown]
# **Explanation:** `toupper()` converts letters to uppercase.

# %%
job <- "data scientist"
toupper(job)
# Out:
# [1] "DATA SCIENTIST"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "DATA SCIENTIST"
# ```

# %% [markdown]
# ## 5. Convert a String to Lowercase
#
# ### Practical Question
#
# Convert `"PYTHON FOR DATA SCIENCE"` to lowercase.
#
# ### Answer
#
# ```r
# course <- "PYTHON FOR DATA SCIENCE"
# tolower(course)
# ```

# %% [markdown]
# **Explanation:** `tolower()` converts letters to lowercase.

# %%
course <- "PYTHON FOR DATA SCIENCE"
tolower(course)
# Out:
# [1] "python for data science"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "python for data science"
# ```

# %% [markdown]
# ## 6. Extract Characters from a String
#
# ### Practical Question
#
# Given `text <- "Artificial Intelligence"`, extract the first 10 characters.
#
# ### Answer
#
# ```r
# text <- "Artificial Intelligence"
# substr(text, 1, 10)
# ```

# %% [markdown]
# **Explanation:** `substr(x, start, stop)` extracts characters between the specified positions.

# %%
text <- "Artificial Intelligence"
substr(text, 1, 10)
# Out:
# [1] "Artificial"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "Artificial"
# ```

# %% [markdown]
# ## 7. Extract a Specific Character
#
# ### Practical Question
#
# Given `text <- "Artificial Intelligence"`, extract the 3rd character.
#
# ### Answer
#
# ```r
# text <- "Artificial Intelligence"
# substr(text, 3, 3)
# ```

# %% [markdown]
# **Explanation:** Using the same start and stop position extracts one character.

# %%
text <- "Artificial Intelligence"
substr(text, 3, 3)
# Out:
# [1] "t"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "t"
# ```

# %% [markdown]
# ## 8. Replace Part of a String
#
# ### Practical Question
#
# Change `"Python"` to `"R"` in `"I am learning Python"`.
#
# ### Answer
#
# ```r
# text <- "I am learning Python"
# sub("Python", "R", text)
# ```

# %% [markdown]
# **Explanation:** `sub()` replaces the first matching occurrence.

# %%
text <- "I am learning Python"
sub("Python", "R", text)
# Out:
# [1] "I am learning R"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "I am learning R"
# ```

# %% [markdown]
# ## 9. Replace All Occurrences
#
# ### Practical Question
#
# Replace every occurrence of `"Python"` with `"R"` in `"Python is great. Python is powerful."`.
#
# ### Answer
#
# ```r
# text <- "Python is great. Python is powerful."
# gsub("Python", "R", text)
# ```

# %% [markdown]
# **Explanation:** `gsub()` replaces all matching occurrences. Remember: `sub()` replaces the first occurrence, while `gsub()` replaces all occurrences.

# %%
text <- "Python is great. Python is powerful."
gsub("Python", "R", text)
# Out:
# [1] "R is great. R is powerful."

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "R is great. R is powerful."
# ```

# %% [markdown]
# ## 10. Combine Strings
#
# ### Practical Question
#
# Combine `first_name <- "Gbenga"` and `last_name <- "Kajola"` into `"Gbenga Kajola"`.
#
# ### Answer
#
# ```r
# first_name <- "Gbenga"
# last_name <- "Kajola"
# paste(first_name, last_name)
# ```

# %% [markdown]
# **Explanation:** `paste()` combines strings and inserts a space by default.

# %%
first_name <- "Gbenga"
last_name <- "Kajola"
paste(first_name, last_name)
# Out:
# [1] "Gbenga Kajola"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "Gbenga Kajola"
# ```

# %% [markdown]
# ## 11. Create a Sentence from Variables
#
# ### Practical Question
#
# Given a name, profession, and years of experience, create the sentence: `Gbenga is a Data Scientist with 5 years of experience.`
#
# ### Answer
#
# ```r
# name <- "Gbenga"
# profession <- "Data Scientist"
# experience <- 5
#
# paste(name, "is a", profession, "with", experience, "years of experience.")
# ```

# %% [markdown]
# **Explanation:** `paste()` can combine both strings and numeric values into a readable sentence.

# %%
name <- "Gbenga"
profession <- "Data Scientist"
experience <- 5

paste(name, "is a", profession, "with", experience, "years of experience.")
# Out:
# [1] "Gbenga is a Data Scientist with 5 years of experience."

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "Gbenga is a Data Scientist with 5 years of experience."
# ```

# %% [markdown]
# ## 12. Check Whether a String Contains a Word
#
# ### Practical Question
#
# Determine whether `"Python"` exists in `"I am learning Python for Data Science"`.
#
# ### Answer
#
# ```r
# text <- "I am learning Python for Data Science"
# grepl("Python", text)
# ```

# %% [markdown]
# **Explanation:** `grepl()` returns `TRUE` when a pattern is found and `FALSE` otherwise.

# %%
text <- "I am learning Python for Data Science"
grepl("Python", text)
# Out:
# [1] TRUE

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] TRUE
# ```

# %% [markdown]
# ## 13. Find Matching Elements
#
# ### Practical Question
#
# Find the vector element that contains `"Python"`.
#
# ### Answer
#
# ```r
# text <- c(
#   "I am learning Python",
#   "I am learning R",
#   "I am learning SQL"
# )
#
# grep("Python", text)
# ```

# %% [markdown]
# **Explanation:** `grep()` returns the positions of elements that match the pattern.

# %%
text <- c(
  "I am learning Python",
  "I am learning R",
  "I am learning SQL"
)

grep("Python", text)
# Out:
# [1] 1

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] 1
# ```

# %% [markdown]
# ## 14. Find the Character Position of a Word
#
# ### Practical Question
#
# Find the character position where `"Python"` starts in `"I am learning Python"`.
#
# ### Answer
#
# ```r
# text <- "I am learning Python"
# regexpr("Python", text)
# ```

# %% [markdown]
# **Explanation:** `regexpr()` searches for a pattern and reports its starting character position.

# %%
text <- "I am learning Python"
regexpr("Python", text)
# Out:
# [1] 15
# attr(,"match.length")
# [1] 6
# attr(,"index.type")
# [1] "chars"
# attr(,"useBytes")
# [1] TRUE

# %% [markdown]
# **Expected output:**
#
# ```text
#      Python
# [1,]      15
# ```

# %% [markdown]
# ## 15. Split a String
#
# ### Practical Question
#
# Split `"Python R SQL PowerBI"` into individual words.
#
# ### Answer
#
# ```r
# text <- "Python R SQL PowerBI"
# strsplit(text, " ")
# ```

# %% [markdown]
# **Explanation:** `strsplit()` breaks a string according to a separator. Here, the separator is a space.

# %%
text <- "Python R SQL PowerBI"
strsplit(text, " ")
# Out:
# [[1]]
# [1] "Python"  "R"       "SQL"     "PowerBI"

# %% [markdown]
# **Expected output:**
#
# ```text
# [[1]]
# [1] "Python" "R" "SQL" "PowerBI"
# ```

# %% [markdown]
# ## 16. Split an Email Address
#
# ### Practical Question
#
# Separate the username and domain from `"gbenga@gmail.com"`.
#
# ### Answer
#
# ```r
# email <- "gbenga@gmail.com"
# strsplit(email, "@")
# ```

# %% [markdown]
# **Explanation:** The `@` symbol is used as the separator.

# %%
email <- "gbenga@gmail.com"
strsplit(email, "@")
# Out:
# [[1]]
# [1] "gbenga"    "gmail.com"

# %% [markdown]
# **Expected output:**
#
# ```text
# [[1]]
# [1] "gbenga" "gmail.com"
# ```

# %% [markdown]
# ## 17. Remove Extra Spaces
#
# ### Practical Question
#
# Remove leading and trailing spaces from `"   Gbenga Kajola   "`.
#
# ### Answer
#
# ```r
# name <- "   Gbenga Kajola   "
# trimws(name)
# ```

# %% [markdown]
# **Explanation:** `trimws()` removes whitespace from the beginning and end of a string.

# %%
name <- "   Gbenga Kajola   "
trimws(name)
# Out:
# [1] "Gbenga Kajola"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "Gbenga Kajola"
# ```

# %% [markdown]
# ## 18. Clean Customer Names
#
# ### Practical Question
#
# Given `customers <- c("JOHN", "mary", "PETER", "susan")`, convert the names so that the first letter is uppercase and the remaining letters are lowercase.
#
# ### Answer
#
# ```r
# customers <- c("JOHN", "mary", "PETER", "susan")
#
# customers <- paste0(
#   toupper(substr(customers, 1, 1)),
#   tolower(substr(customers, 2, nchar(customers)))
# )
#
# print(customers)
# ```

# %% [markdown]
# **Explanation:** `substr()` extracts the first and remaining characters, while `toupper()` and `tolower()` standardize the case. `paste0()` joins the pieces without adding a space.

# %%
customers <- c("JOHN", "mary", "PETER", "susan")

customers <- paste0(
  toupper(substr(customers, 1, 1)),
  tolower(substr(customers, 2, nchar(customers)))
)

print(customers)
# Out:
# [1] "John"  "Mary"  "Peter" "Susan"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "John"  "Mary"  "Peter" "Susan"
# ```

# %% [markdown]
# ## 19. Extract Email Domains
#
# ### Practical Question
#
# Given a vector of email addresses, extract only the domain portion after `@`.
#
# ### Answer
#
# ```r
# emails <- c(
#   "john@gmail.com",
#   "mary@yahoo.com",
#   "peter@outlook.com"
# )
#
# sapply(strsplit(emails, "@"), `[`, 2)
# ```

# %% [markdown]
# **Explanation:** `strsplit()` separates each email into two pieces. `sapply()` extracts the second piece, which is the domain.

# %%
emails <- c(
  "john@gmail.com",
  "mary@yahoo.com",
  "peter@outlook.com"
)

sapply(strsplit(emails, "@"), `[`, 2)
# Out:
# [1] "gmail.com"   "yahoo.com"   "outlook.com"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "gmail.com"   "yahoo.com"   "outlook.com"
# ```

# %% [markdown]
# ## 20. Identify Customers from Gmail
#
# ### Practical Question
#
# Given a vector of email addresses, identify which addresses use Gmail.
#
# ### Answer
#
# ```r
# emails <- c(
#   "john@gmail.com",
#   "mary@yahoo.com",
#   "peter@gmail.com",
#   "susan@outlook.com"
# )
#
# grepl("@gmail.com", emails)
# ```

# %% [markdown]
# **Explanation:** `grepl()` works element-by-element on a character vector and returns a logical vector.

# %%
emails <- c(
  "john@gmail.com",
  "mary@yahoo.com",
  "peter@gmail.com",
  "susan@outlook.com"
)

grepl("@gmail.com", emails)
# Out:
# [1]  TRUE FALSE  TRUE FALSE

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] TRUE FALSE TRUE FALSE
# ```

# %% [markdown]
# ## 21. Display Only Gmail Customers
#
# ### Practical Question
#
# Using the same email vector, display only the Gmail addresses.
#
# ### Answer
#
# ```r
# emails <- c(
#   "john@gmail.com",
#   "mary@yahoo.com",
#   "peter@gmail.com",
#   "susan@outlook.com"
# )
#
# emails[grepl("@gmail.com", emails)]
# ```

# %% [markdown]
# **Explanation:** The logical vector returned by `grepl()` can be used to filter the original vector.

# %%
emails <- c(
  "john@gmail.com",
  "mary@yahoo.com",
  "peter@gmail.com",
  "susan@outlook.com"
)

emails[grepl("@gmail.com", emails)]
# Out:
# [1] "john@gmail.com"  "peter@gmail.com"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "john@gmail.com"  "peter@gmail.com"
# ```

# %% [markdown]
# ## 22. Clean Phone Numbers
#
# ### Practical Question
#
# Given phone numbers containing spaces and hyphens, remove both characters.
#
# ### Answer
#
# ```r
# phones <- c(
#   "080-123-4567",
#   "081 234 5678",
#   "070-555-1234"
# )
#
# phones <- gsub("[- ]", "", phones)
#
# print(phones)
# ```

# %% [markdown]
# **Explanation:** `gsub()` can use a regular expression. `[- ]` means either a hyphen or a space.

# %%
phones <- c(
  "080-123-4567",
  "081 234 5678",
  "070-555-1234"
)

phones <- gsub("[- ]", "", phones)

print(phones)
# Out:
# [1] "0801234567" "0812345678" "0705551234"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "0801234567" "0812345678" "0705551234"
# ```

# %% [markdown]
# ## 23. Count the Number of Words
#
# ### Practical Question
#
# Given `"I am learning R programming"`, count the number of words.
#
# ### Answer
#
# ```r
# sentence <- "I am learning R programming"
#
# words <- strsplit(sentence, " ")[[1]]
# length(words)
# ```

# %% [markdown]
# **Explanation:** `strsplit()` creates a vector of words and `length()` counts the elements.

# %%
sentence <- "I am learning R programming"

words <- strsplit(sentence, " ")[[1]]
length(words)
# Out:
# [1] 5

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] 5
# ```

# %% [markdown]
# # 24. Challenge: Customer Data Cleaning
#
# ### Practical Question
#
# You receive the following customer names:
#
# ```r
# customers <- c(
#   "  JOHN DOE",
#   "mary jane  ",
#   "PETER SMITH",
#   "  Susan Williams "
# )
# ```
#
# Perform the following tasks:
#
# 1. Remove unnecessary leading and trailing spaces.
# 2. Convert all names to lowercase.
# 3. Convert the first character of each name to uppercase.
# 4. Display the cleaned names.
#
# ### Answer

# %%
customers <- c(
  "  JOHN DOE",
  "mary jane  ",
  "PETER SMITH",
  "  Susan Williams "
)

# Step 1: Remove leading and trailing spaces
customers <- trimws(customers)

# Step 2: Convert all names to lowercase
customers <- tolower(customers)

# Step 3: Convert the first character of each name to uppercase
customers <- paste0(
  toupper(substr(customers, 1, 1)),
  substr(customers, 2, nchar(customers))
)

# Step 4: Display the cleaned names
print(customers)
# Out:
# [1] "John doe"       "Mary jane"      "Peter smith"    "Susan williams"

# %% [markdown]
# **Expected output:**
#
# ```text
# [1] "John doe"
# [2] "Mary jane"
# [3] "Peter smith"
# [4] "Susan williams"
# ```
#
# ### Note
#
# This solution capitalizes only the first character of the complete string. If you want **every word** in a person's name to be title-cased (for example, `John Doe` rather than `John doe`), you would use a different approach or a string-processing package such as `stringr`.

# %% [markdown]
# # 25. String Functions Quick Reference
#
# | Function | Purpose | Example |
# |---|---|---|
# | `nchar()` | Count characters | `nchar("Hello")` |
# | `toupper()` | Convert to uppercase | `toupper("hello")` |
# | `tolower()` | Convert to lowercase | `tolower("HELLO")` |
# | `substr()` | Extract characters | `substr("Hello", 1, 2)` |
# | `substring()` | Extract characters | `substring("Hello", 1, 2)` |
# | `paste()` | Combine strings with a separator | `paste("Data", "Science")` |
# | `paste0()` | Combine strings without a separator | `paste0("Data", "Science")` |
# | `sub()` | Replace first occurrence | `sub("R", "Python", text)` |
# | `gsub()` | Replace all occurrences | `gsub("R", "Python", text)` |
# | `strsplit()` | Split a string | `strsplit("A B C", " ")` |
# | `trimws()` | Remove leading/trailing whitespace | `trimws(text)` |
# | `grepl()` | Test whether a pattern exists | `grepl("R", text)` |
# | `grep()` | Find matching vector elements | `grep("R", text)` |
# | `regexpr()` | Find character position of a pattern | `regexpr("R", text)` |
# | `length()` | Count vector elements | `length(words)` |
# | `sapply()` | Apply a function over elements | `sapply(x, function)` |
#
# ## Key Distinctions
#
# ### `sub()` vs `gsub()`
# - `sub()` → first matching occurrence
# - `gsub()` → every matching occurrence
#
# ### `grep()` vs `grepl()`
# - `grep()` → returns matching positions
# - `grepl()` → returns `TRUE`/`FALSE`
#
# ### `paste()` vs `paste0()`
# - `paste()` → inserts a separator (space by default)
# - `paste0()` → no separator by default

# %% [markdown]
# # 26. Mini Data-Cleaning Project
#
# ## Customer Contact Data
#
# Imagine you receive this raw customer contact information:
#
# ```r
# customers <- c(
#   " JOHN DOE ",
#   "mary.jane@gmail.com",
#   "080-123-4567"
# )
# ```
#
# Your task is to identify what each string represents and clean it appropriately.
#
# ### Suggested Workflow
#
# 1. Use `trimws()` to remove unnecessary spaces.
# 2. Use `tolower()` where standardized lowercase text is appropriate.
# 3. Use `grepl()` to detect email addresses.
# 4. Use `strsplit()` to separate email usernames and domains.
# 5. Use `gsub()` to remove unwanted characters from phone numbers.
# 6. Use `nchar()` to validate string lengths.
#
# This type of string manipulation is common during **ETL, data cleaning, exploratory data analysis, customer analytics, fraud detection, and machine learning preprocessing**.

# %% [markdown]
# # 27. Practice Exercises - Try Before Looking at the Answers
#
# ## Exercise 1
# Create a variable:
#
# ```r
# course <- "Data Science with R"
# ```
#
# Find its number of characters.
#
# ## Exercise 2
# Convert:
#
# ```r
# job <- "MACHINE LEARNING ENGINEER"
# ```
#
# to lowercase.
#
# ## Exercise 3
# Extract `"Data"` from:
#
# ```r
# text <- "Data Science"
# ```
#
# ## Exercise 4
# Replace `"SQL"` with `"Python"`:
#
# ```r
# text <- "I am learning SQL"
# ```
#
# ## Exercise 5
# Check whether `"AI"` exists in:
#
# ```r
# text <- "Artificial Intelligence"
# ```
#
# ## Exercise 6
# Split this sentence into individual words:
#
# ```r
# sentence <- "R is useful for data analysis"
# ```
#
# ## Exercise 7
# Extract the domain from:
#
# ```r
# email <- "analyst@company.com"
# ```
#
# ## Exercise 8
# Remove hyphens from:
#
# ```r
# phone <- "080-555-1234"
# ```
#
# ## Exercise 9
# Count the number of words in:
#
# ```r
# sentence <- "I love data science and artificial intelligence"
# ```
#
# ## Exercise 10 - Data Cleaning
# Clean this vector:
#
# ```r
# names <- c(" JOHN", "mary ", " PETER ", "susan")
# ```
#
# The final output should look like:
#
# ```text
# "John" "Mary" "Peter" "Susan"
# ```

# %% [markdown]
# # 28. Final Takeaways
#
# R string manipulation is an essential skill for working with real-world data.
#
# The most important functions in this notebook are:
#
# ```r
# nchar()
# toupper()
# tolower()
# substr()
# paste()
# paste0()
# sub()
# gsub()
# strsplit()
# trimws()
# grepl()
# grep()
# regexpr()
# ```
#
# ### In Data Analytics
#
# String functions are frequently used to:
#
# - Clean customer names
# - Standardize categories
# - Extract email domains
# - Validate phone numbers
# - Search transaction descriptions
# - Detect keywords
# - Prepare text before analysis
# - Create new variables from existing text
# - Prepare categorical/text features for machine learning
#
# ### Recommended Learning Progression
#
# **Basic strings → String indexing → Case conversion → Extraction → Replacement → Searching → Splitting → Regular expressions → Data cleaning → Text preprocessing**
#
# Once these fundamentals are comfortable, the next natural step is learning **`stringr`**, R's powerful string-processing package, including functions such as `str_detect()`, `str_extract()`, `str_replace()`, `str_replace_all()`, `str_split()`, and `str_trim()`.
